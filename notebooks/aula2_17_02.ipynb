# %% [markdown]
# <a href="https://colab.research.google.com/github/lucascerfig/fci-cienciadedados/blob/main/notebooks/aula2_17_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importando nosso conjunto

# %%
url = "https://raw.githubusercontent.com/lucascerfig/fci-cienciadedados/main/datasets/aula2_igngames.csv"
df = pd.read_csv(url)

# removendo a primeira coluna (indice vazio)
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

df.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# ...

# %% [markdown]
# Obtendo algumas métricas sobre nosso conjunto de dados

# %%
df.describe()
# Out:
#               score  release_year  release_month   release_day
# count  18625.000000  18625.000000    18625.00000  18625.000000
# mean       6.950459   2006.515329        7.13847     15.603866
# std        1.711736      4.587529        3.47671      8.690128
# min        0.500000   1970.000000        1.00000      1.000000
# 25%        6.000000   2003.000000        4.00000      8.000000
# 50%        7.300000   2007.000000        8.00000     16.000000
# 75%        8.200000   2010.000000       10.00000     23.000000
# max       10.000000   2016.000000       12.00000     31.000000

# %% [markdown]
# df.info() nos informa os tipos de dados e dados nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18625 entries, 0 to 18624
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   score_phrase    18625 non-null  object
#  1   title           18625 non-null  object
#  2   url             18625 non-null  object
#  3   platform        18625 non-null  object
#  4   score           18625 non-null  float64
#  5   genre           18589 non-null  object
#  6   editors_choice  18625 non-null  object
#  7   release_year    18625 non-null  int64
#  8   release_month   18625 non-null  int64
#  9   release_day     18625 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.4+ MB

# %%
# Histograma da coluna 'score'
plt.figure(figsize=(10, 6))
sns.histplot(df['score'], bins=20, kde=True)  # kde=True adiciona a curva de densidade
plt.title('Distribuição de Scores dos Jogos')
plt.xlabel('Score')
plt.ylabel('Frequência')
plt.show()

# %%
# Histograma da coluna 'year'
plt.figure(figsize=(10, 6))
sns.histplot(df['release_year'], bins=20, kde=True)
plt.title('Distribuição do ano de lançamento dos Jogos')
plt.xlabel('Score')
plt.ylabel('Frequência')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 8))
sns.boxplot(x='release_year', y='score', data=df)
plt.title('Distribuição de Score por Ano de Lançamento')
plt.xlabel('Ano de Lançamento')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()
